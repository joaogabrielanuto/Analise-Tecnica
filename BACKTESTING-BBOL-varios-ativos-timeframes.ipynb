# %% [markdown]
# <img src="https://tradingcomdados.com/images/logotipo/logotipo-trading-com-dados.svg" width="300" align="left"/>

# %% [markdown]
# ------
# # **Backtesting definitivo RSI**
# ------

# %% [markdown]
# # 1. Bibliotecas

# %%
# %pip install --upgrade --no-cache-dir git+https://github.com/StreamAlpha/tvdatafeed.git

# %%
# Análise e manipulação de dados
import numpy as np
import pandas as pd

# Dados séries temporais
from datetime import datetime, timedelta
import pytz

# Fonte de dados
from tvDatafeed import TvDatafeed, Interval
import MetaTrader5 as mt5

# Indicadores e backtesting
import ta
import vectorbt as vbt

# Bibliotecas gráficas
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # 2.Obtenção de dados

# %% [markdown]
# ## 2.1. Cotações OHLC - TradingView - Week a 5min

# %%
lista_tickers = ['WDO1!', 'WIN1!', 'ABEV3', 'ALPA4', 'ALSO3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3', 'BBAS3', 'BBDC3', 'BBDC4',
                'BBSE3', 'BEEF3', 'BPAC11', 'BPAN4', 'BRAP4', 'BRFS3', 'BRKM5', 'CASH3', 'CCRO3', 'CIEL3', 'CMIG4', 'CMIN3',
                'COGN3', 'CPFE3', 'CPLE6', 'CRFB3', 'CSAN3', 'CSNA3', 'CVCB3', 'CYRE3', 'DXCO3', 'ECOR3', 'EGIE3', 'ELET3',
                'ELET6', 'EMBR3', 'ENBR3', 'ENEV3', 'ENGI11', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4', 'HAPV3',
                'HYPE3', 'IGTI11', 'ITSA4', 'ITUB4', 'JBSS3', 'KLBN11', 'LREN3', 'LWSA3', 'MGLU3', 'MRFG3', 'MRVE3', 'MULT3',
                'NTCO3', 'PCAR3', 'PETR3', 'PETR4', 'PETZ3', 'PRIO3', 'QUAL3', 'RADL3', 'RAIL3', 'RAIZ4', 'RDOR3', 'RENT3',
                'RRRP3', 'SANB11', 'SBSP3', 'SLCE3', 'SMTO3', 'SOMA3', 'SUZB3', 'TAEE11', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5',
                'VALE3', 'VBBR3', 'VIIA3', 'VIVT3', 'WEGE3', 'YDUQ3']

# %%
timeframes = [Interval.in_weekly, Interval.in_daily, Interval.in_1_hour,
                Interval.in_15_minute, Interval.in_5_minute]

# %%
cotacoes_tv_all = []

for ticker in lista_tickers:

    cotacoes_tv_ativo = []

    for timeframe in timeframes:

        cotacoes_tv_ativo_timef = TvDatafeed().get_hist(symbol=ticker, exchange='BMFBOVESPA', interval=timeframe, n_bars=10000)
        cotacoes_tv_ativo_timef['symbol'] = cotacoes_tv_ativo_timef['symbol'].str.replace('BMFBOVESPA:', '')
        cotacoes_tv_ativo_timef['timeframe'] = str(timeframe)[12:]

        cotacoes_tv_ativo.append(cotacoes_tv_ativo_timef)
    
    cotacoes_tv_all.append(cotacoes_tv_ativo)
# Out:
# you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
list(enumerate(lista_tickers))[0:5]
# Out:
# [(0, 'WDO1!'), (1, 'WIN1!'), (2, 'ABEV3'), (3, 'ALPA4'), (4, 'ALSO3')]

# %%
timeframes_str = []
for i in timeframes:
    timeframes_str.append(str(i)[12:])
    
list(enumerate(timeframes_str))
# Out:
# [(0, 'weekly'), (1, 'daily'), (2, '1_hour'), (3, '15_minute'), (4, '5_minute')]

# %%
cotacoes_tv_all[1][3]
# Out:
#                     symbol      open      high       low     close    volume  \
# datetime
# 2022-09-01 09:00:00  WIN1!  111250.0  111415.0  110825.0  111185.0  618107.0
# 2022-09-01 09:15:00  WIN1!  111185.0  111505.0  111150.0  111350.0  359003.0
# 2022-09-01 09:30:00  WIN1!  111350.0  111495.0  111210.0  111245.0  485551.0
# 2022-09-01 09:45:00  WIN1!  111245.0  111390.0  111020.0  111270.0  523212.0
# 2022-09-01 10:00:00  WIN1!  111270.0  111485.0  110935.0  111175.0  971894.0
# ...                    ...       ...       ...       ...       ...       ...
# 2023-03-30 09:00:00  WIN1!  103680.0  104030.0  103570.0  103730.0  476896.0
# 2023-03-30 09:15:00  WIN1!  103735.0  103950.0  103560.0  103790.0  404150.0
# 2023-03-30 09:30:00  WIN1!  103795.0  104200.0  103745.0  103985.0  616797.0
# 2023-03-30 09:45:00  WIN1!  103980.0  104035.0  103665.0  103700.0  339850.0
# 2023-03-30 10:00:00  WIN1!  103705.0  103710.0  103670.0  103670.0    5416.0
#
#                      timeframe
# datetime
# 2022-09-01 09:00:00  15_minute
# 2022-09-01 09:15:00  15_minute
# 2022-09-01 09:30:00  15_minute
# 2022-09-01 09:45:00  15_minute
# 2022-09-01 10:00:00  15_minute
# ...                        ...
# 2023-03-30 09:00:00  15_minute
# 2023-03-30 09:15:00  15_minute
# 2023-03-30 09:30:00  15_minute
# 2023-03-30 09:45:00  15_minute
# 2023-03-30 10:00:00  15_minute
#
# [5366 rows x 7 columns]

# %% [markdown]
# ## 2.2. Cotações OHLC - TradingView - Monthly a Diario

# %%
lista_tickers = ['WDO1!', 'WIN1!', 'ABEV3', 'ALPA4', 'ALSO3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3', 'BBAS3', 'BBDC3', 'BBDC4',
                'BBSE3', 'BEEF3', 'BPAC11', 'BPAN4', 'BRAP4', 'BRFS3', 'BRKM5', 'CASH3', 'CCRO3', 'CIEL3', 'CMIG4', 'CMIN3',
                'COGN3', 'CPFE3', 'CPLE6', 'CRFB3', 'CSAN3', 'CSNA3', 'CVCB3', 'CYRE3', 'DXCO3', 'ECOR3', 'EGIE3', 'ELET3',
                'ELET6', 'EMBR3', 'ENBR3', 'ENEV3', 'ENGI11', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4', 'HAPV3',
                'HYPE3', 'IGTI11', 'ITSA4', 'ITUB4', 'JBSS3', 'KLBN11', 'LREN3', 'LWSA3', 'MGLU3', 'MRFG3', 'MRVE3', 'MULT3',
                'NTCO3', 'PCAR3', 'PETR3', 'PETR4', 'PETZ3', 'PRIO3', 'QUAL3', 'RADL3', 'RAIL3', 'RAIZ4', 'RDOR3', 'RENT3',
                'RRRP3', 'SANB11', 'SBSP3', 'SLCE3', 'SMTO3', 'SOMA3', 'SUZB3', 'TAEE11', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5',
                'VALE3', 'VBBR3', 'VIIA3', 'VIVT3', 'WEGE3', 'YDUQ3']

# %%
timeframes = [Interval.in_monthly, Interval.in_weekly, Interval.in_daily]

# %%
cotacoes_tv_all = []

for ticker in lista_tickers:

    cotacoes_tv_ativo = []

    for timeframe in timeframes:

        cotacoes_tv_ativo_timef = TvDatafeed().get_hist(symbol=ticker, exchange='BMFBOVESPA', interval=timeframe, n_bars=10000)
        cotacoes_tv_ativo_timef['symbol'] = cotacoes_tv_ativo_timef['symbol'].str.replace('BMFBOVESPA:', '')
        cotacoes_tv_ativo_timef['timeframe'] = str(timeframe)[12:]

        cotacoes_tv_ativo.append(cotacoes_tv_ativo_timef)
    
    cotacoes_tv_all.append(cotacoes_tv_ativo)
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited

# %%
#list(enumerate(lista_tickers))

# %% [markdown]
# ## 2.3. Cotações OHLC - MetaTrader

# %%
mt5.initialize()

# %%
lista_tickers = ['WDO$', 'WIN$', 'ABEV3', 'ALPA4', 'ALSO3', 'ARZZ3', 'ASAI3', 'AZUL4', 'B3SA3', 'BBAS3', 'BBDC3', 'BBDC4',
                'BBSE3', 'BEEF3', 'BPAC11', 'BPAN4', 'BRAP4', 'BRFS3', 'BRKM5', 'CASH3', 'CCRO3', 'CIEL3', 'CMIG4', 'CMIN3',
                'COGN3', 'CPFE3', 'CPLE6', 'CRFB3', 'CSAN3', 'CSNA3', 'CVCB3', 'CYRE3', 'DXCO3', 'ECOR3', 'EGIE3', 'ELET3',
                'ELET6', 'EMBR3', 'ENBR3', 'ENEV3', 'ENGI11', 'EQTL3', 'EZTC3', 'FLRY3', 'GGBR4', 'GOAU4', 'GOLL4', 'HAPV3',
                'HYPE3', 'IGTI11', 'ITSA4', 'ITUB4', 'JBSS3', 'KLBN11', 'LREN3', 'LWSA3', 'MGLU3', 'MRFG3', 'MRVE3', 'MULT3',
                'NTCO3', 'PCAR3', 'PETR3', 'PETR4', 'PETZ3', 'PRIO3', 'QUAL3', 'RADL3', 'RAIL3', 'RAIZ4', 'RDOR3', 'RENT3',
                'RRRP3', 'SANB11', 'SBSP3', 'SLCE3', 'SMTO3', 'SOMA3', 'SUZB3', 'TAEE11', 'TIMS3', 'TOTS3', 'UGPA3', 'USIM5',
                'VALE3', 'VBBR3', 'VIIA3', 'VIVT3', 'WEGE3', 'YDUQ3']

# %%
for i in lista_tickers:
    selected=mt5.symbol_select(i, True)
    if not selected:
        print(i,"não localizado")
timeframes = [32769, 16408, 16385, 15, 5]
timezone = pytz.timezone("America/Sao_Paulo")
data_inicio = datetime(2013, 1, 1)
data_fim = datetime(2022, 12, 31)
data_inicio
timezone = pytz.timezone("America/Sao_Paulo")
data_inicio = datetime.now() - timedelta(days=10000)
data_fim = datetime.now()

cotacoes_mt5_all = []

for ticker in lista_tickers:

    cotacoes_mt5_ativo = []

    for timeframe in timeframes:

        cotacoes_mt5_ticker = mt5.copy_rates_range(ticker, timeframe, data_inicio, data_fim)
        cotacoes_mt5_ticker = pd.DataFrame(cotacoes_mt5_ticker)
        cotacoes_mt5_ticker['ticker'] = str(ticker)

        if timeframe==32769:
            cotacoes_mt5_ticker['timeframe'] = '1W'
        elif timeframe==16408:
            cotacoes_mt5_ticker['timeframe'] = '1D'
        elif timeframe==16385:
            cotacoes_mt5_ticker['timeframe'] = '1H'
        else:
            cotacoes_mt5_ticker['timeframe'] = str(timeframe)+'M'
        
        cotacoes_mt5_ticker.index = pd.to_datetime(cotacoes_mt5_ticker['time'], unit='s')
        cotacoes_mt5_ticker = cotacoes_mt5_ticker.drop('time', axis=1)
        cotacoes_mt5_ativo.append(cotacoes_mt5_ticker)
    
    cotacoes_mt5_all.append(cotacoes_mt5_ativo)
list(enumerate(lista_tickers))[0:5]
timeframes_str = ['1W', '1D', '1H', '15M', '5M']
list(enumerate(timeframes_str))
cotacoes_mt5_all[2][0]

# %% [markdown]
# ## 2.4. Cálculo indicadores

# %%
dados_ohlc = cotacoes_tv_all.copy()

# %%
periodo_indicadores = 20
desv_pad = 2

# %%
for i in range(len(dados_ohlc)):
    for j in range(len(dados_ohlc[i])):
        dados_ohlc[i][j]['Bol_sup'] = ta.volatility.BollingerBands(dados_ohlc[i][j].close, window=periodo_indicadores, window_dev=desv_pad).bollinger_hband()
        dados_ohlc[i][j]['Bol_inf'] = ta.volatility.BollingerBands(dados_ohlc[i][j].close, window=periodo_indicadores, window_dev=desv_pad).bollinger_lband()
        dados_ohlc[i][j]['Bol_media'] = ta.volatility.BollingerBands(dados_ohlc[i][j].close, window=periodo_indicadores, window_dev=desv_pad).bollinger_mavg()

# %% [markdown]
# # 3. Backtesting

# %%
for i in range(len(dados_ohlc)):

    for j in range(len(dados_ohlc[i])):

        dados_ohlc[i][j]['entrada'] = dados_ohlc[i][j]['close'].vbt.crossed_above(dados_ohlc[i][j]['Bol_inf'])
        dados_ohlc[i][j]['saida'] = dados_ohlc[i][j]['close'].vbt.crossed_above(dados_ohlc[i][j]['Bol_media'])
        #dados_ohlc[i][j]['saida'] = dados_ohlc[i][j]['close'].vbt.crossed_above(dados_ohlc[i][j]['Bol_sup'])
        #dados_ohlc[i][j]['short_entrada'] = dados_ohlc[i][j]['close'].vbt.crossed_below(dados_ohlc[i][j]['Bol_sup'])
        #dados_ohlc[i][j]['short_saida'] = dados_ohlc[i][j]['close'].vbt.crossed_below(dados_ohlc[i][j]['Bol_media'])
        #dados_ohlc[i][j]['short_saida'] = dados_ohlc[i][j]['close'].vbt.crossed_below(dados_ohlc[i][j]['Bol_inf'])

# %%
ls_backtests_all = []

for i in range(len(dados_ohlc)):

    ls_backtests_ativo = []

    for j in range(len(dados_ohlc[i])):

        backtest_ativo = vbt.Portfolio.from_signals(dados_ohlc[i][j].close, entries=dados_ohlc[i][j].entrada, exits=dados_ohlc[i][j].saida,
                                                    #short_entries=dados_ohlc[i][j].short_entrada, short_exits=dados_ohlc[i][j].short_saida,
                                                    fees=0.00005,
                                                    size_type='Value', size=1,
                                                    )
        ls_backtests_ativo.append(backtest_ativo)

    ls_backtests_all.append(ls_backtests_ativo)

# %%
ls_ativos = []
ls_timeframes = []
ls_retorno = []
ls_n_trades = []
ls_annualized_return = []
ls_min_pnl = []


for i in range(len(ls_backtests_all)):

    for j in range(len(ls_backtests_ativo)):

        ls_ativos.append(i)
        ls_timeframes.append(j)
        
        ls_n_trades.append(ls_backtests_all[i][j].trades.count())

        ls_annualized_return = []

        lista_pnl = list(ls_backtests_all[i][j].trades.pnl.values)
        cash_init = [100]
        if lista_pnl == []:
            ls_min_pnl.append(1)
        else:
            ls_min_pnl.append(min(lista_pnl))
        for index,pnl in enumerate(lista_pnl):
            if pnl<=-1:
                pnl=0
                cash_init.append(cash_init[index]*pnl)
            else:
                cash_init.append(cash_init[index]*(1+pnl))
        if min(cash_init)==0:
            ls_retorno.append(0)
        else:
            ls_retorno.append(cash_init[-1])

# %%
from datetime import datetime as dt
import time

def toYearFraction(date):
    def sinceEpoch(date): # returns seconds since epoch
        return time.mktime(date.timetuple())
    s = sinceEpoch

    year = date.year
    startOfThisYear = dt(year=year, month=1, day=1)
    startOfNextYear = dt(year=year+1, month=1, day=1)

    yearElapsed = s(date) - s(startOfThisYear)
    yearDuration = s(startOfNextYear) - s(startOfThisYear)
    fraction = yearElapsed/yearDuration

    return date.year + fraction

# %%
ls_ativos = []
ls_timeframes = []
ls_data_init = []
ls_year_init = []
ls_n_candles = []

for i in range(len(dados_ohlc)):

    for j in range(len(dados_ohlc[i])):

        ls_ativos.append(i)
        ls_timeframes.append(j)
        ls_data_init.append(dados_ohlc[i][j].index[0])
        ls_year_init.append(toYearFraction(dados_ohlc[i][j].index[0]))
        ls_n_candles.append(len(dados_ohlc[i][j]))

df_result_01 = pd.DataFrame([ls_ativos, ls_timeframes, ls_retorno, ls_n_trades, ls_min_pnl, ls_data_init, ls_year_init, ls_n_candles], \
                            index=['Ativo', 'Timeframe', 'Cash_final', 'N_trades', 'Min_PnL', 'Data_init', 'Ano_init','N_candles']).transpose()
df_result_01['Tempo_em_anos'] = toYearFraction(dt.now()) - df_result_01.Ano_init
df_result_01['Retorno_annualizado']  = (df_result_01.Cash_final/100)**(1/df_result_01.Tempo_em_anos) - 1
df_result_01 = df_result_01[df_result_01.N_trades>0]


result_final = pd.pivot_table(df_result_01, values="Retorno_annualizado", index=["Ativo"], columns=["Timeframe"], aggfunc='mean')
result_final = round(result_final*100,1)
result_final.index = lista_tickers

timeframes_reduzido = [str(i)[12:] for i in timeframes]
result_final.columns = timeframes_reduzido

# %%
result_final[:15].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_4c6ca_row0_col0, #T_4c6ca_row0_col1, #T_4c6ca_row0_col2, #T_4c6ca_row1_col0, #T_4c6ca_row1_col1, #T_4c6ca_row2_col0, #T_4c6ca_row2_col1, #T_4c6ca_row2_col2, #T_4c6ca_row3_col0, #T_4c6ca_row3_col1, #T_4c6ca_row3_col2, #T_4c6ca_row4_col1, #T_4c6ca_row5_col1, #T_4c6ca_row5_col2, #T_4c6ca_row7_col1, #T_4c6ca_row8_col0, #T_4c6ca_row8_col1, #T_4c6ca_row8_col2, #T_4c6ca_row9_col0, #T_4c6ca_row9_col1, #T_4c6ca_row9_col2, #T_4c6ca_row10_col0, #T_4c6ca_row10_col1, #T_4c6ca_row10_col2, #T_4c6ca_row11_col0, #T_4c6ca_row11_col1, #T_4c6ca_row11_col2, #T_4c6ca_row12_col0, #T_4c6ca_row12_col1, #T_4c6ca_row13_col0, #T_4c6ca_row14_col1 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_4c6ca_row1_col2, #T_4c6ca_row4_col0, #T_4c6ca_row4_col2, #T_4c6ca_row5_col0, #T_4c6ca_row6_col1, #T_4c6ca_row6_col2, #T_4c6ca_row7_col2, #T_4c6ca_row12_col2, #T_4c6ca_row13_col1, #T_4c6ca_row13_col2, #T_4c6ca_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_4c6ca_row6_col0, #T_4c6ca_row14_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# #T_4c6ca_row7_col0 {
#   font-weight: ;
#   color: black;
#   background-color: #43CD80;
# }
# </style>
# <table id="T_4c6ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c6ca_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_4c6ca_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_4c6ca_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c6ca_level0_row0" class="row_heading level0 row0" >WDO1!</th>
#       <td id="T_4c6ca_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_4c6ca_row0_col1" class="data row0 col1" >0.20</td>
#       <td id="T_4c6ca_row0_col2" class="data row0 col2" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row1" class="row_heading level0 row1" >WIN1!</th>
#       <td id="T_4c6ca_row1_col0" class="data row1 col0" >5.90</td>
#       <td id="T_4c6ca_row1_col1" class="data row1 col1" >6.20</td>
#       <td id="T_4c6ca_row1_col2" class="data row1 col2" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row2" class="row_heading level0 row2" >ABEV3</th>
#       <td id="T_4c6ca_row2_col0" class="data row2 col0" >1.30</td>
#       <td id="T_4c6ca_row2_col1" class="data row2 col1" >2.70</td>
#       <td id="T_4c6ca_row2_col2" class="data row2 col2" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row3" class="row_heading level0 row3" >ALPA4</th>
#       <td id="T_4c6ca_row3_col0" class="data row3 col0" >3.80</td>
#       <td id="T_4c6ca_row3_col1" class="data row3 col1" >7.50</td>
#       <td id="T_4c6ca_row3_col2" class="data row3 col2" >7.70</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row4" class="row_heading level0 row4" >ALSO3</th>
#       <td id="T_4c6ca_row4_col0" class="data row4 col0" >-0.90</td>
#       <td id="T_4c6ca_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_4c6ca_row4_col2" class="data row4 col2" >-0.60</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row5" class="row_heading level0 row5" >ARZZ3</th>
#       <td id="T_4c6ca_row5_col0" class="data row5 col0" >-0.60</td>
#       <td id="T_4c6ca_row5_col1" class="data row5 col1" >4.00</td>
#       <td id="T_4c6ca_row5_col2" class="data row5 col2" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row6" class="row_heading level0 row6" >ASAI3</th>
#       <td id="T_4c6ca_row6_col0" class="data row6 col0" ></td>
#       <td id="T_4c6ca_row6_col1" class="data row6 col1" >-16.30</td>
#       <td id="T_4c6ca_row6_col2" class="data row6 col2" >-20.80</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row7" class="row_heading level0 row7" >AZUL4</th>
#       <td id="T_4c6ca_row7_col0" class="data row7 col0" >13.00</td>
#       <td id="T_4c6ca_row7_col1" class="data row7 col1" >4.50</td>
#       <td id="T_4c6ca_row7_col2" class="data row7 col2" >-8.40</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row8" class="row_heading level0 row8" >B3SA3</th>
#       <td id="T_4c6ca_row8_col0" class="data row8 col0" >1.10</td>
#       <td id="T_4c6ca_row8_col1" class="data row8 col1" >3.90</td>
#       <td id="T_4c6ca_row8_col2" class="data row8 col2" >7.10</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row9" class="row_heading level0 row9" >BBAS3</th>
#       <td id="T_4c6ca_row9_col0" class="data row9 col0" >3.10</td>
#       <td id="T_4c6ca_row9_col1" class="data row9 col1" >9.70</td>
#       <td id="T_4c6ca_row9_col2" class="data row9 col2" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row10" class="row_heading level0 row10" >BBDC3</th>
#       <td id="T_4c6ca_row10_col0" class="data row10 col0" >3.80</td>
#       <td id="T_4c6ca_row10_col1" class="data row10 col1" >6.20</td>
#       <td id="T_4c6ca_row10_col2" class="data row10 col2" >4.20</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row11" class="row_heading level0 row11" >BBDC4</th>
#       <td id="T_4c6ca_row11_col0" class="data row11 col0" >5.30</td>
#       <td id="T_4c6ca_row11_col1" class="data row11 col1" >5.00</td>
#       <td id="T_4c6ca_row11_col2" class="data row11 col2" >1.50</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row12" class="row_heading level0 row12" >BBSE3</th>
#       <td id="T_4c6ca_row12_col0" class="data row12 col0" >2.10</td>
#       <td id="T_4c6ca_row12_col1" class="data row12 col1" >5.60</td>
#       <td id="T_4c6ca_row12_col2" class="data row12 col2" >-1.30</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row13" class="row_heading level0 row13" >BEEF3</th>
#       <td id="T_4c6ca_row13_col0" class="data row13 col0" >2.80</td>
#       <td id="T_4c6ca_row13_col1" class="data row13 col1" >-4.50</td>
#       <td id="T_4c6ca_row13_col2" class="data row13 col2" >-5.30</td>
#     </tr>
#     <tr>
#       <th id="T_4c6ca_level0_row14" class="row_heading level0 row14" >BPAC11</th>
#       <td id="T_4c6ca_row14_col0" class="data row14 col0" ></td>
#       <td id="T_4c6ca_row14_col1" class="data row14 col1" >6.40</td>
#       <td id="T_4c6ca_row14_col2" class="data row14 col2" >-6.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
result_final[15:30].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_a0c69_row0_col0, #T_a0c69_row4_col0, #T_a0c69_row8_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# #T_a0c69_row0_col1, #T_a0c69_row0_col2, #T_a0c69_row1_col2, #T_a0c69_row2_col0, #T_a0c69_row2_col1, #T_a0c69_row3_col2, #T_a0c69_row4_col1, #T_a0c69_row6_col0, #T_a0c69_row6_col1, #T_a0c69_row8_col1, #T_a0c69_row9_col1, #T_a0c69_row9_col2, #T_a0c69_row12_col1, #T_a0c69_row14_col0, #T_a0c69_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_a0c69_row1_col0, #T_a0c69_row1_col1, #T_a0c69_row2_col2, #T_a0c69_row3_col0, #T_a0c69_row3_col1, #T_a0c69_row5_col0, #T_a0c69_row5_col1, #T_a0c69_row5_col2, #T_a0c69_row6_col2, #T_a0c69_row7_col0, #T_a0c69_row7_col1, #T_a0c69_row7_col2, #T_a0c69_row9_col0, #T_a0c69_row10_col0, #T_a0c69_row10_col1, #T_a0c69_row10_col2, #T_a0c69_row11_col0, #T_a0c69_row11_col1, #T_a0c69_row11_col2, #T_a0c69_row12_col0, #T_a0c69_row12_col2, #T_a0c69_row13_col0, #T_a0c69_row13_col1, #T_a0c69_row13_col2, #T_a0c69_row14_col1 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_a0c69_row4_col2, #T_a0c69_row8_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #43CD80;
# }
# </style>
# <table id="T_a0c69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0c69_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_a0c69_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_a0c69_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0c69_level0_row0" class="row_heading level0 row0" >BPAN4</th>
#       <td id="T_a0c69_row0_col0" class="data row0 col0" ></td>
#       <td id="T_a0c69_row0_col1" class="data row0 col1" >-3.40</td>
#       <td id="T_a0c69_row0_col2" class="data row0 col2" >-9.00</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row1" class="row_heading level0 row1" >BRAP4</th>
#       <td id="T_a0c69_row1_col0" class="data row1 col0" >1.90</td>
#       <td id="T_a0c69_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_a0c69_row1_col2" class="data row1 col2" >-1.50</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row2" class="row_heading level0 row2" >BRFS3</th>
#       <td id="T_a0c69_row2_col0" class="data row2 col0" >-5.80</td>
#       <td id="T_a0c69_row2_col1" class="data row2 col1" >-2.10</td>
#       <td id="T_a0c69_row2_col2" class="data row2 col2" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row3" class="row_heading level0 row3" >BRKM5</th>
#       <td id="T_a0c69_row3_col0" class="data row3 col0" >4.00</td>
#       <td id="T_a0c69_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_a0c69_row3_col2" class="data row3 col2" >-4.50</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row4" class="row_heading level0 row4" >CASH3</th>
#       <td id="T_a0c69_row4_col0" class="data row4 col0" ></td>
#       <td id="T_a0c69_row4_col1" class="data row4 col1" >-5.90</td>
#       <td id="T_a0c69_row4_col2" class="data row4 col2" >11.90</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row5" class="row_heading level0 row5" >CCRO3</th>
#       <td id="T_a0c69_row5_col0" class="data row5 col0" >3.90</td>
#       <td id="T_a0c69_row5_col1" class="data row5 col1" >0.30</td>
#       <td id="T_a0c69_row5_col2" class="data row5 col2" >5.70</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row6" class="row_heading level0 row6" >CIEL3</th>
#       <td id="T_a0c69_row6_col0" class="data row6 col0" >-9.30</td>
#       <td id="T_a0c69_row6_col1" class="data row6 col1" >-0.90</td>
#       <td id="T_a0c69_row6_col2" class="data row6 col2" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row7" class="row_heading level0 row7" >CMIG4</th>
#       <td id="T_a0c69_row7_col0" class="data row7 col0" >1.40</td>
#       <td id="T_a0c69_row7_col1" class="data row7 col1" >4.50</td>
#       <td id="T_a0c69_row7_col2" class="data row7 col2" >3.30</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row8" class="row_heading level0 row8" >CMIN3</th>
#       <td id="T_a0c69_row8_col0" class="data row8 col0" ></td>
#       <td id="T_a0c69_row8_col1" class="data row8 col1" >-14.50</td>
#       <td id="T_a0c69_row8_col2" class="data row8 col2" >17.50</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row9" class="row_heading level0 row9" >COGN3</th>
#       <td id="T_a0c69_row9_col0" class="data row9 col0" >1.40</td>
#       <td id="T_a0c69_row9_col1" class="data row9 col1" >-3.00</td>
#       <td id="T_a0c69_row9_col2" class="data row9 col2" >-8.70</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row10" class="row_heading level0 row10" >CPFE3</th>
#       <td id="T_a0c69_row10_col0" class="data row10 col0" >1.90</td>
#       <td id="T_a0c69_row10_col1" class="data row10 col1" >7.10</td>
#       <td id="T_a0c69_row10_col2" class="data row10 col2" >4.80</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row11" class="row_heading level0 row11" >CPLE6</th>
#       <td id="T_a0c69_row11_col0" class="data row11 col0" >1.70</td>
#       <td id="T_a0c69_row11_col1" class="data row11 col1" >3.80</td>
#       <td id="T_a0c69_row11_col2" class="data row11 col2" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row12" class="row_heading level0 row12" >CRFB3</th>
#       <td id="T_a0c69_row12_col0" class="data row12 col0" >3.90</td>
#       <td id="T_a0c69_row12_col1" class="data row12 col1" >-6.50</td>
#       <td id="T_a0c69_row12_col2" class="data row12 col2" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row13" class="row_heading level0 row13" >CSAN3</th>
#       <td id="T_a0c69_row13_col0" class="data row13 col0" >3.30</td>
#       <td id="T_a0c69_row13_col1" class="data row13 col1" >3.10</td>
#       <td id="T_a0c69_row13_col2" class="data row13 col2" >1.20</td>
#     </tr>
#     <tr>
#       <th id="T_a0c69_level0_row14" class="row_heading level0 row14" >CSNA3</th>
#       <td id="T_a0c69_row14_col0" class="data row14 col0" >-0.50</td>
#       <td id="T_a0c69_row14_col1" class="data row14 col1" >2.00</td>
#       <td id="T_a0c69_row14_col2" class="data row14 col2" >-8.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
result_final[30:45].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_fe1d9_row0_col0, #T_fe1d9_row0_col1, #T_fe1d9_row0_col2, #T_fe1d9_row2_col2, #T_fe1d9_row3_col0, #T_fe1d9_row3_col2, #T_fe1d9_row5_col0, #T_fe1d9_row6_col2, #T_fe1d9_row7_col2, #T_fe1d9_row9_col0, #T_fe1d9_row9_col1, #T_fe1d9_row9_col2, #T_fe1d9_row12_col0, #T_fe1d9_row12_col2, #T_fe1d9_row13_col0 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_fe1d9_row1_col0, #T_fe1d9_row1_col1, #T_fe1d9_row1_col2, #T_fe1d9_row2_col0, #T_fe1d9_row2_col1, #T_fe1d9_row3_col1, #T_fe1d9_row4_col1, #T_fe1d9_row4_col2, #T_fe1d9_row5_col1, #T_fe1d9_row5_col2, #T_fe1d9_row6_col0, #T_fe1d9_row6_col1, #T_fe1d9_row7_col0, #T_fe1d9_row7_col1, #T_fe1d9_row8_col0, #T_fe1d9_row8_col1, #T_fe1d9_row8_col2, #T_fe1d9_row10_col0, #T_fe1d9_row10_col1, #T_fe1d9_row10_col2, #T_fe1d9_row11_col0, #T_fe1d9_row11_col1, #T_fe1d9_row11_col2, #T_fe1d9_row12_col1, #T_fe1d9_row13_col1, #T_fe1d9_row13_col2, #T_fe1d9_row14_col0, #T_fe1d9_row14_col1, #T_fe1d9_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_fe1d9_row4_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# </style>
# <table id="T_fe1d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe1d9_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_fe1d9_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_fe1d9_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe1d9_level0_row0" class="row_heading level0 row0" >CVCB3</th>
#       <td id="T_fe1d9_row0_col0" class="data row0 col0" >-3.90</td>
#       <td id="T_fe1d9_row0_col1" class="data row0 col1" >-12.10</td>
#       <td id="T_fe1d9_row0_col2" class="data row0 col2" >-11.90</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row1" class="row_heading level0 row1" >CYRE3</th>
#       <td id="T_fe1d9_row1_col0" class="data row1 col0" >3.40</td>
#       <td id="T_fe1d9_row1_col1" class="data row1 col1" >4.10</td>
#       <td id="T_fe1d9_row1_col2" class="data row1 col2" >3.20</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row2" class="row_heading level0 row2" >DXCO3</th>
#       <td id="T_fe1d9_row2_col0" class="data row2 col0" >2.20</td>
#       <td id="T_fe1d9_row2_col1" class="data row2 col1" >1.70</td>
#       <td id="T_fe1d9_row2_col2" class="data row2 col2" >-0.80</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row3" class="row_heading level0 row3" >ECOR3</th>
#       <td id="T_fe1d9_row3_col0" class="data row3 col0" >-3.50</td>
#       <td id="T_fe1d9_row3_col1" class="data row3 col1" >2.90</td>
#       <td id="T_fe1d9_row3_col2" class="data row3 col2" >-8.20</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row4" class="row_heading level0 row4" >EGIE3</th>
#       <td id="T_fe1d9_row4_col0" class="data row4 col0" ></td>
#       <td id="T_fe1d9_row4_col1" class="data row4 col1" >4.40</td>
#       <td id="T_fe1d9_row4_col2" class="data row4 col2" >7.70</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row5" class="row_heading level0 row5" >ELET3</th>
#       <td id="T_fe1d9_row5_col0" class="data row5 col0" >-2.90</td>
#       <td id="T_fe1d9_row5_col1" class="data row5 col1" >2.50</td>
#       <td id="T_fe1d9_row5_col2" class="data row5 col2" >4.90</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row6" class="row_heading level0 row6" >ELET6</th>
#       <td id="T_fe1d9_row6_col0" class="data row6 col0" >2.40</td>
#       <td id="T_fe1d9_row6_col1" class="data row6 col1" >0.30</td>
#       <td id="T_fe1d9_row6_col2" class="data row6 col2" >-1.60</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row7" class="row_heading level0 row7" >EMBR3</th>
#       <td id="T_fe1d9_row7_col0" class="data row7 col0" >1.60</td>
#       <td id="T_fe1d9_row7_col1" class="data row7 col1" >4.20</td>
#       <td id="T_fe1d9_row7_col2" class="data row7 col2" >-3.50</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row8" class="row_heading level0 row8" >ENBR3</th>
#       <td id="T_fe1d9_row8_col0" class="data row8 col0" >0.90</td>
#       <td id="T_fe1d9_row8_col1" class="data row8 col1" >3.20</td>
#       <td id="T_fe1d9_row8_col2" class="data row8 col2" >6.50</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row9" class="row_heading level0 row9" >ENEV3</th>
#       <td id="T_fe1d9_row9_col0" class="data row9 col0" >-17.70</td>
#       <td id="T_fe1d9_row9_col1" class="data row9 col1" >-25.00</td>
#       <td id="T_fe1d9_row9_col2" class="data row9 col2" >-13.80</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row10" class="row_heading level0 row10" >ENGI11</th>
#       <td id="T_fe1d9_row10_col0" class="data row10 col0" >0.70</td>
#       <td id="T_fe1d9_row10_col1" class="data row10 col1" >6.50</td>
#       <td id="T_fe1d9_row10_col2" class="data row10 col2" >6.10</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row11" class="row_heading level0 row11" >EQTL3</th>
#       <td id="T_fe1d9_row11_col0" class="data row11 col0" >3.20</td>
#       <td id="T_fe1d9_row11_col1" class="data row11 col1" >0.30</td>
#       <td id="T_fe1d9_row11_col2" class="data row11 col2" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row12" class="row_heading level0 row12" >EZTC3</th>
#       <td id="T_fe1d9_row12_col0" class="data row12 col0" >-2.90</td>
#       <td id="T_fe1d9_row12_col1" class="data row12 col1" >3.10</td>
#       <td id="T_fe1d9_row12_col2" class="data row12 col2" >-0.80</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row13" class="row_heading level0 row13" >FLRY3</th>
#       <td id="T_fe1d9_row13_col0" class="data row13 col0" >-0.60</td>
#       <td id="T_fe1d9_row13_col1" class="data row13 col1" >4.80</td>
#       <td id="T_fe1d9_row13_col2" class="data row13 col2" >6.90</td>
#     </tr>
#     <tr>
#       <th id="T_fe1d9_level0_row14" class="row_heading level0 row14" >GGBR4</th>
#       <td id="T_fe1d9_row14_col0" class="data row14 col0" >4.20</td>
#       <td id="T_fe1d9_row14_col1" class="data row14 col1" >7.30</td>
#       <td id="T_fe1d9_row14_col2" class="data row14 col2" >5.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
result_final[45:60].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_c5ae5_row0_col0, #T_c5ae5_row0_col1, #T_c5ae5_row0_col2, #T_c5ae5_row3_col0, #T_c5ae5_row3_col1, #T_c5ae5_row4_col1, #T_c5ae5_row5_col0, #T_c5ae5_row5_col1, #T_c5ae5_row5_col2, #T_c5ae5_row6_col0, #T_c5ae5_row6_col1, #T_c5ae5_row6_col2, #T_c5ae5_row7_col0, #T_c5ae5_row7_col1, #T_c5ae5_row8_col1, #T_c5ae5_row8_col2, #T_c5ae5_row9_col0, #T_c5ae5_row9_col1, #T_c5ae5_row9_col2, #T_c5ae5_row12_col0, #T_c5ae5_row13_col0, #T_c5ae5_row13_col1, #T_c5ae5_row13_col2, #T_c5ae5_row14_col0, #T_c5ae5_row14_col1, #T_c5ae5_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_c5ae5_row1_col0, #T_c5ae5_row1_col1, #T_c5ae5_row1_col2, #T_c5ae5_row2_col0, #T_c5ae5_row2_col1, #T_c5ae5_row2_col2, #T_c5ae5_row3_col2, #T_c5ae5_row7_col2, #T_c5ae5_row8_col0, #T_c5ae5_row11_col0, #T_c5ae5_row11_col1, #T_c5ae5_row11_col2, #T_c5ae5_row12_col1, #T_c5ae5_row12_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_c5ae5_row4_col0, #T_c5ae5_row10_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# #T_c5ae5_row4_col2 {
#   font-weight: ;
#   color: white;
#   background-color: forestgreen;
# }
# #T_c5ae5_row10_col1 {
#   font-weight: ;
#   color: white;
#   background-color: #CD0000;
# }
# #T_c5ae5_row10_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #43CD80;
# }
# </style>
# <table id="T_c5ae5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5ae5_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_c5ae5_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_c5ae5_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5ae5_level0_row0" class="row_heading level0 row0" >GOAU4</th>
#       <td id="T_c5ae5_row0_col0" class="data row0 col0" >5.70</td>
#       <td id="T_c5ae5_row0_col1" class="data row0 col1" >-0.00</td>
#       <td id="T_c5ae5_row0_col2" class="data row0 col2" >2.80</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row1" class="row_heading level0 row1" >GOLL4</th>
#       <td id="T_c5ae5_row1_col0" class="data row1 col0" >-4.10</td>
#       <td id="T_c5ae5_row1_col1" class="data row1 col1" >-7.80</td>
#       <td id="T_c5ae5_row1_col2" class="data row1 col2" >-8.30</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row2" class="row_heading level0 row2" >HAPV3</th>
#       <td id="T_c5ae5_row2_col0" class="data row2 col0" >-14.50</td>
#       <td id="T_c5ae5_row2_col1" class="data row2 col1" >-0.80</td>
#       <td id="T_c5ae5_row2_col2" class="data row2 col2" >-11.90</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row3" class="row_heading level0 row3" >HYPE3</th>
#       <td id="T_c5ae5_row3_col0" class="data row3 col0" >0.70</td>
#       <td id="T_c5ae5_row3_col1" class="data row3 col1" >6.00</td>
#       <td id="T_c5ae5_row3_col2" class="data row3 col2" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row4" class="row_heading level0 row4" >IGTI11</th>
#       <td id="T_c5ae5_row4_col0" class="data row4 col0" ></td>
#       <td id="T_c5ae5_row4_col1" class="data row4 col1" >4.10</td>
#       <td id="T_c5ae5_row4_col2" class="data row4 col2" >34.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row5" class="row_heading level0 row5" >ITSA4</th>
#       <td id="T_c5ae5_row5_col0" class="data row5 col0" >1.40</td>
#       <td id="T_c5ae5_row5_col1" class="data row5 col1" >6.80</td>
#       <td id="T_c5ae5_row5_col2" class="data row5 col2" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row6" class="row_heading level0 row6" >ITUB4</th>
#       <td id="T_c5ae5_row6_col0" class="data row6 col0" >2.50</td>
#       <td id="T_c5ae5_row6_col1" class="data row6 col1" >7.80</td>
#       <td id="T_c5ae5_row6_col2" class="data row6 col2" >8.80</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row7" class="row_heading level0 row7" >JBSS3</th>
#       <td id="T_c5ae5_row7_col0" class="data row7 col0" >4.70</td>
#       <td id="T_c5ae5_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_c5ae5_row7_col2" class="data row7 col2" >-1.10</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row8" class="row_heading level0 row8" >KLBN11</th>
#       <td id="T_c5ae5_row8_col0" class="data row8 col0" >-1.20</td>
#       <td id="T_c5ae5_row8_col1" class="data row8 col1" >1.80</td>
#       <td id="T_c5ae5_row8_col2" class="data row8 col2" >7.80</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row9" class="row_heading level0 row9" >LREN3</th>
#       <td id="T_c5ae5_row9_col0" class="data row9 col0" >3.80</td>
#       <td id="T_c5ae5_row9_col1" class="data row9 col1" >4.20</td>
#       <td id="T_c5ae5_row9_col2" class="data row9 col2" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row10" class="row_heading level0 row10" >LWSA3</th>
#       <td id="T_c5ae5_row10_col0" class="data row10 col0" ></td>
#       <td id="T_c5ae5_row10_col1" class="data row10 col1" >-30.70</td>
#       <td id="T_c5ae5_row10_col2" class="data row10 col2" >13.40</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row11" class="row_heading level0 row11" >MGLU3</th>
#       <td id="T_c5ae5_row11_col0" class="data row11 col0" >-3.30</td>
#       <td id="T_c5ae5_row11_col1" class="data row11 col1" >-11.80</td>
#       <td id="T_c5ae5_row11_col2" class="data row11 col2" >-13.10</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row12" class="row_heading level0 row12" >MRFG3</th>
#       <td id="T_c5ae5_row12_col0" class="data row12 col0" >9.80</td>
#       <td id="T_c5ae5_row12_col1" class="data row12 col1" >-3.00</td>
#       <td id="T_c5ae5_row12_col2" class="data row12 col2" >-3.70</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row13" class="row_heading level0 row13" >MRVE3</th>
#       <td id="T_c5ae5_row13_col0" class="data row13 col0" >6.70</td>
#       <td id="T_c5ae5_row13_col1" class="data row13 col1" >5.40</td>
#       <td id="T_c5ae5_row13_col2" class="data row13 col2" >1.60</td>
#     </tr>
#     <tr>
#       <th id="T_c5ae5_level0_row14" class="row_heading level0 row14" >MULT3</th>
#       <td id="T_c5ae5_row14_col0" class="data row14 col0" >1.80</td>
#       <td id="T_c5ae5_row14_col1" class="data row14 col1" >5.10</td>
#       <td id="T_c5ae5_row14_col2" class="data row14 col2" >5.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
result_final[60:75].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_cdc02_row0_col0, #T_cdc02_row0_col2, #T_cdc02_row1_col2, #T_cdc02_row2_col2, #T_cdc02_row3_col2, #T_cdc02_row4_col0, #T_cdc02_row4_col1, #T_cdc02_row4_col2, #T_cdc02_row5_col1, #T_cdc02_row5_col2, #T_cdc02_row6_col0, #T_cdc02_row6_col1, #T_cdc02_row6_col2, #T_cdc02_row8_col0, #T_cdc02_row8_col1, #T_cdc02_row8_col2, #T_cdc02_row9_col1, #T_cdc02_row10_col1, #T_cdc02_row10_col2, #T_cdc02_row12_col2, #T_cdc02_row13_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_cdc02_row0_col1, #T_cdc02_row1_col1, #T_cdc02_row2_col0, #T_cdc02_row2_col1, #T_cdc02_row3_col0, #T_cdc02_row3_col1, #T_cdc02_row7_col0, #T_cdc02_row7_col1, #T_cdc02_row7_col2, #T_cdc02_row11_col0, #T_cdc02_row11_col1, #T_cdc02_row11_col2, #T_cdc02_row13_col0, #T_cdc02_row13_col1, #T_cdc02_row14_col0, #T_cdc02_row14_col1, #T_cdc02_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_cdc02_row1_col0, #T_cdc02_row5_col0, #T_cdc02_row9_col0, #T_cdc02_row10_col0, #T_cdc02_row12_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# #T_cdc02_row9_col2, #T_cdc02_row12_col1 {
#   font-weight: ;
#   color: black;
#   background-color: #43CD80;
# }
# </style>
# <table id="T_cdc02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdc02_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_cdc02_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_cdc02_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdc02_level0_row0" class="row_heading level0 row0" >NTCO3</th>
#       <td id="T_cdc02_row0_col0" class="data row0 col0" >-3.60</td>
#       <td id="T_cdc02_row0_col1" class="data row0 col1" >1.30</td>
#       <td id="T_cdc02_row0_col2" class="data row0 col2" >-1.10</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row1" class="row_heading level0 row1" >PCAR3</th>
#       <td id="T_cdc02_row1_col0" class="data row1 col0" ></td>
#       <td id="T_cdc02_row1_col1" class="data row1 col1" >2.50</td>
#       <td id="T_cdc02_row1_col2" class="data row1 col2" >-0.60</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row2" class="row_heading level0 row2" >PETR3</th>
#       <td id="T_cdc02_row2_col0" class="data row2 col0" >4.30</td>
#       <td id="T_cdc02_row2_col1" class="data row2 col1" >4.60</td>
#       <td id="T_cdc02_row2_col2" class="data row2 col2" >-2.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row3" class="row_heading level0 row3" >PETR4</th>
#       <td id="T_cdc02_row3_col0" class="data row3 col0" >3.40</td>
#       <td id="T_cdc02_row3_col1" class="data row3 col1" >5.80</td>
#       <td id="T_cdc02_row3_col2" class="data row3 col2" >-2.40</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row4" class="row_heading level0 row4" >PETZ3</th>
#       <td id="T_cdc02_row4_col0" class="data row4 col0" >-21.00</td>
#       <td id="T_cdc02_row4_col1" class="data row4 col1" >-23.70</td>
#       <td id="T_cdc02_row4_col2" class="data row4 col2" >-0.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row5" class="row_heading level0 row5" >PRIO3</th>
#       <td id="T_cdc02_row5_col0" class="data row5 col0" ></td>
#       <td id="T_cdc02_row5_col1" class="data row5 col1" >-8.30</td>
#       <td id="T_cdc02_row5_col2" class="data row5 col2" >-24.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row6" class="row_heading level0 row6" >QUAL3</th>
#       <td id="T_cdc02_row6_col0" class="data row6 col0" >-10.10</td>
#       <td id="T_cdc02_row6_col1" class="data row6 col1" >-6.30</td>
#       <td id="T_cdc02_row6_col2" class="data row6 col2" >-1.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row7" class="row_heading level0 row7" >RADL3</th>
#       <td id="T_cdc02_row7_col0" class="data row7 col0" >4.40</td>
#       <td id="T_cdc02_row7_col1" class="data row7 col1" >2.40</td>
#       <td id="T_cdc02_row7_col2" class="data row7 col2" >4.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row8" class="row_heading level0 row8" >RAIL3</th>
#       <td id="T_cdc02_row8_col0" class="data row8 col0" >-0.50</td>
#       <td id="T_cdc02_row8_col1" class="data row8 col1" >-4.30</td>
#       <td id="T_cdc02_row8_col2" class="data row8 col2" >-1.10</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row9" class="row_heading level0 row9" >RAIZ4</th>
#       <td id="T_cdc02_row9_col0" class="data row9 col0" ></td>
#       <td id="T_cdc02_row9_col1" class="data row9 col1" >-15.50</td>
#       <td id="T_cdc02_row9_col2" class="data row9 col2" >11.30</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row10" class="row_heading level0 row10" >RDOR3</th>
#       <td id="T_cdc02_row10_col0" class="data row10 col0" ></td>
#       <td id="T_cdc02_row10_col1" class="data row10 col1" >-1.60</td>
#       <td id="T_cdc02_row10_col2" class="data row10 col2" >-21.80</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row11" class="row_heading level0 row11" >RENT3</th>
#       <td id="T_cdc02_row11_col0" class="data row11 col0" >5.10</td>
#       <td id="T_cdc02_row11_col1" class="data row11 col1" >7.40</td>
#       <td id="T_cdc02_row11_col2" class="data row11 col2" >1.90</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row12" class="row_heading level0 row12" >RRRP3</th>
#       <td id="T_cdc02_row12_col0" class="data row12 col0" ></td>
#       <td id="T_cdc02_row12_col1" class="data row12 col1" >18.40</td>
#       <td id="T_cdc02_row12_col2" class="data row12 col2" >-15.50</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row13" class="row_heading level0 row13" >SANB11</th>
#       <td id="T_cdc02_row13_col0" class="data row13 col0" >3.80</td>
#       <td id="T_cdc02_row13_col1" class="data row13 col1" >0.70</td>
#       <td id="T_cdc02_row13_col2" class="data row13 col2" >-1.10</td>
#     </tr>
#     <tr>
#       <th id="T_cdc02_level0_row14" class="row_heading level0 row14" >SBSP3</th>
#       <td id="T_cdc02_row14_col0" class="data row14 col0" >2.40</td>
#       <td id="T_cdc02_row14_col1" class="data row14 col1" >5.90</td>
#       <td id="T_cdc02_row14_col2" class="data row14 col2" >3.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
result_final[75:].style.format('{:.2f}', na_rep="").applymap(lambda x: "font-weight: ; color: white; background-color : #CD0000" if x < -25 \
                                                        else ( "font-weight: ; color: black; background-color : #FF6666" if x <0 \
                                                              else ("font-weight: ; color: black; background-color : #C1FFC1" if x <10 \
                                                                  else ("font-weight: ; color: black; background-color : #43CD80" if x <20 \
                                                                        else ("font-weight: ; color: white; background-color : forestgreen" if x <100 \
                                                                              else ("font-weight: ; color: black; background-color : lightgray"))))))
# Out:
# <style type="text/css">
# #T_8553c_row0_col0, #T_8553c_row0_col1, #T_8553c_row0_col2, #T_8553c_row1_col0, #T_8553c_row1_col2, #T_8553c_row3_col1, #T_8553c_row3_col2, #T_8553c_row4_col0, #T_8553c_row4_col1, #T_8553c_row4_col2, #T_8553c_row5_col1, #T_8553c_row5_col2, #T_8553c_row6_col0, #T_8553c_row6_col1, #T_8553c_row7_col0, #T_8553c_row7_col1, #T_8553c_row7_col2, #T_8553c_row8_col0, #T_8553c_row8_col1, #T_8553c_row9_col0, #T_8553c_row9_col1, #T_8553c_row9_col2, #T_8553c_row10_col0, #T_8553c_row10_col1, #T_8553c_row10_col2, #T_8553c_row11_col0, #T_8553c_row11_col1, #T_8553c_row12_col0, #T_8553c_row12_col1, #T_8553c_row12_col2, #T_8553c_row13_col0, #T_8553c_row13_col1, #T_8553c_row13_col2, #T_8553c_row14_col1 {
#   font-weight: ;
#   color: black;
#   background-color: #C1FFC1;
# }
# #T_8553c_row1_col1, #T_8553c_row2_col1, #T_8553c_row5_col0, #T_8553c_row6_col2, #T_8553c_row8_col2, #T_8553c_row11_col2, #T_8553c_row14_col2 {
#   font-weight: ;
#   color: black;
#   background-color: #FF6666;
# }
# #T_8553c_row2_col0 {
#   font-weight: ;
#   color: black;
#   background-color: #43CD80;
# }
# #T_8553c_row2_col2 {
#   font-weight: ;
#   color: white;
#   background-color: forestgreen;
# }
# #T_8553c_row3_col0, #T_8553c_row14_col0 {
#   font-weight: ;
#   color: black;
#   background-color: lightgray;
# }
# </style>
# <table id="T_8553c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8553c_level0_col0" class="col_heading level0 col0" >monthly</th>
#       <th id="T_8553c_level0_col1" class="col_heading level0 col1" >weekly</th>
#       <th id="T_8553c_level0_col2" class="col_heading level0 col2" >daily</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8553c_level0_row0" class="row_heading level0 row0" >SLCE3</th>
#       <td id="T_8553c_row0_col0" class="data row0 col0" >1.40</td>
#       <td id="T_8553c_row0_col1" class="data row0 col1" >4.20</td>
#       <td id="T_8553c_row0_col2" class="data row0 col2" >7.90</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row1" class="row_heading level0 row1" >SMTO3</th>
#       <td id="T_8553c_row1_col0" class="data row1 col0" >2.20</td>
#       <td id="T_8553c_row1_col1" class="data row1 col1" >-0.20</td>
#       <td id="T_8553c_row1_col2" class="data row1 col2" >6.70</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row2" class="row_heading level0 row2" >SOMA3</th>
#       <td id="T_8553c_row2_col0" class="data row2 col0" >13.50</td>
#       <td id="T_8553c_row2_col1" class="data row2 col1" >-2.30</td>
#       <td id="T_8553c_row2_col2" class="data row2 col2" >24.80</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row3" class="row_heading level0 row3" >SUZB3</th>
#       <td id="T_8553c_row3_col0" class="data row3 col0" ></td>
#       <td id="T_8553c_row3_col1" class="data row3 col1" >7.50</td>
#       <td id="T_8553c_row3_col2" class="data row3 col2" >5.50</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row4" class="row_heading level0 row4" >TAEE11</th>
#       <td id="T_8553c_row4_col0" class="data row4 col0" >3.20</td>
#       <td id="T_8553c_row4_col1" class="data row4 col1" >2.40</td>
#       <td id="T_8553c_row4_col2" class="data row4 col2" >1.80</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row5" class="row_heading level0 row5" >TIMS3</th>
#       <td id="T_8553c_row5_col0" class="data row5 col0" >-1.00</td>
#       <td id="T_8553c_row5_col1" class="data row5 col1" >4.50</td>
#       <td id="T_8553c_row5_col2" class="data row5 col2" >1.50</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row6" class="row_heading level0 row6" >TOTS3</th>
#       <td id="T_8553c_row6_col0" class="data row6 col0" >7.90</td>
#       <td id="T_8553c_row6_col1" class="data row6 col1" >5.40</td>
#       <td id="T_8553c_row6_col2" class="data row6 col2" >-5.70</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row7" class="row_heading level0 row7" >UGPA3</th>
#       <td id="T_8553c_row7_col0" class="data row7 col0" >2.40</td>
#       <td id="T_8553c_row7_col1" class="data row7 col1" >6.10</td>
#       <td id="T_8553c_row7_col2" class="data row7 col2" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row8" class="row_heading level0 row8" >USIM5</th>
#       <td id="T_8553c_row8_col0" class="data row8 col0" >0.80</td>
#       <td id="T_8553c_row8_col1" class="data row8 col1" >3.30</td>
#       <td id="T_8553c_row8_col2" class="data row8 col2" >-3.80</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row9" class="row_heading level0 row9" >VALE3</th>
#       <td id="T_8553c_row9_col0" class="data row9 col0" >1.40</td>
#       <td id="T_8553c_row9_col1" class="data row9 col1" >3.40</td>
#       <td id="T_8553c_row9_col2" class="data row9 col2" >6.70</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row10" class="row_heading level0 row10" >VBBR3</th>
#       <td id="T_8553c_row10_col0" class="data row10 col0" >4.10</td>
#       <td id="T_8553c_row10_col1" class="data row10 col1" >7.80</td>
#       <td id="T_8553c_row10_col2" class="data row10 col2" >3.30</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row11" class="row_heading level0 row11" >VIIA3</th>
#       <td id="T_8553c_row11_col0" class="data row11 col0" >5.40</td>
#       <td id="T_8553c_row11_col1" class="data row11 col1" >0.10</td>
#       <td id="T_8553c_row11_col2" class="data row11 col2" >-9.10</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row12" class="row_heading level0 row12" >VIVT3</th>
#       <td id="T_8553c_row12_col0" class="data row12 col0" >0.60</td>
#       <td id="T_8553c_row12_col1" class="data row12 col1" >2.00</td>
#       <td id="T_8553c_row12_col2" class="data row12 col2" >7.50</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row13" class="row_heading level0 row13" >WEGE3</th>
#       <td id="T_8553c_row13_col0" class="data row13 col0" >2.90</td>
#       <td id="T_8553c_row13_col1" class="data row13 col1" >2.20</td>
#       <td id="T_8553c_row13_col2" class="data row13 col2" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_8553c_level0_row14" class="row_heading level0 row14" >YDUQ3</th>
#       <td id="T_8553c_row14_col0" class="data row14 col0" ></td>
#       <td id="T_8553c_row14_col1" class="data row14 col1" >5.80</td>
#       <td id="T_8553c_row14_col2" class="data row14 col2" >-8.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
round(result_final.describe(),2)
# Out:
#        monthly  weekly  daily
# count    75.00   90.00  90.00
# mean      1.11    0.72   0.33
# std       5.50    7.59   8.67
# min     -21.00  -30.70 -24.90
# 25%      -0.50   -0.65  -3.35
# 50%       1.90    2.60   0.40
# 75%       3.80    5.07   5.12
# max      13.50   18.40  34.00

# %%
fig_box = go.Figure()

fig_box.add_trace(go.Box(
            y=result_final.monthly[~result_final.monthly.isna()],
            name="Monthly",
            marker_color="red",
            boxpoints="all", boxmean=True))

fig_box.add_trace(go.Box(
            y=result_final.monthly[~result_final.weekly.isna()],
            name="Weekly",
            marker_color="blue",
            boxpoints="all", boxmean=True))

fig_box.add_trace(go.Box(
            y=result_final.daily[~result_final.daily.isna()],
            name="Daily",
            marker_color="green",
            boxpoints="all", boxmean=True))

fig_box.update_layout(title='', xaxis_title="<b>Timeframes",
                yaxis_title="<b>Retorno anualizado %", legend_title="",
                font=dict(family="Arial, Arial, Arial",size=22,color="black"),
                margin=dict(l=50, r=20, t=20, b=20), template = 'ggplot2', paper_bgcolor="#f7f8fa",
                legend=dict(orientation="v",yanchor="bottom",y=0.83,xanchor="right",x=0.20),
                yaxis=dict(range=[-40, 40]),
                width=1000,height=1000)

fig_box.show()
